# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns

# %%
tickers = ["ABEV3.SA", "ITSA4.SA", "WEGE3.SA", "USIM5.SA", "VALE3.SA"]
carteira = web.get_data_yahoo(tickers, start='2015')['Adj Close']
ibov = web.get_data_yahoo("^BVSP", start='2015')['Adj Close']

# %%
carteira
# Out:
# Symbols      ABEV3.SA   ITSA4.SA   WEGE3.SA   USIM5.SA   VALE3.SA
# Date
# 2015-01-02  13.735766   4.623532  10.323507   4.620475  17.272886
# 2015-01-05  13.487113   4.638659  10.393835   4.340738  17.013140
# 2015-01-06  14.001563   4.673955  10.239674   4.552952  17.694967
# 2015-01-07  14.198765   4.850426  10.122375   4.823043  18.344326
# 2015-01-08  14.264312   4.900849  10.293266   4.581891  18.539129
# ...               ...        ...        ...        ...        ...
# 2020-12-17  16.059999  11.670000  75.731995  13.710000  87.199997
# 2020-12-18  15.990000  11.640000  73.493118  14.450000  88.190002
# 2020-12-21  15.420000  11.380000  72.010002  14.240000  86.860001
# 2020-12-22  15.510000  11.400000  72.820000  13.970000  86.940002
# 2020-12-23  15.500000  11.670000  72.620003  14.620000  87.360001
#
# [1485 rows x 5 columns]

# %%
ibov
# Out:
# Date
# 2015-01-02     48512.0
# 2015-01-05     47517.0
# 2015-01-06     48001.0
# 2015-01-07     49463.0
# 2015-01-08     49943.0
#                 ...
# 2020-12-17    118157.0
# 2020-12-18    117679.0
# 2020-12-21    116016.0
# 2020-12-22    116348.0
# 2020-12-23    117857.0
# Name: Adj Close, Length: 1477, dtype: float64

# %%
sns.set()
carteira.plot(figsize=(22,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
carteira_normalizada = (carteira/carteira.iloc[0])*100
carteira_normalizada
# Out:
# Symbols       ABEV3.SA    ITSA4.SA    WEGE3.SA    USIM5.SA    VALE3.SA
# Date
# 2015-01-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2015-01-05   98.189738  100.327168  100.681239   93.945719   98.496218
# 2015-01-06  101.935070  101.090576   99.187934   98.538624  102.443604
# 2015-01-07  103.370750  104.907382   98.051701  104.384150  106.203015
# 2015-01-08  103.847950  105.997959   99.707066   99.164929  107.330813
# ...                ...         ...         ...         ...         ...
# 2020-12-17  116.921029  252.404450  733.587843  296.722752  504.837440
# 2020-12-18  116.411413  251.755602  711.900676  312.738417  510.568998
# 2020-12-21  112.261665  246.132190  697.534278  308.193429  502.869059
# 2020-12-22  112.916890  246.564749  705.380425  302.349884  503.332223
# 2020-12-23  112.844086  252.404450  703.443128  316.417694  505.763769
#
# [1485 rows x 5 columns]

# %%
carteira_normalizada.plot(figsize=(22,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
carteira_normalizada['Saldo'] = carteira_normalizada.sum(axis=1)
carteira_normalizada
# Out:
# Symbols       ABEV3.SA    ITSA4.SA  ...    VALE3.SA        Saldo
# Date                                ...
# 2015-01-02  100.000000  100.000000  ...  100.000000   500.000000
# 2015-01-05   98.189738  100.327168  ...   98.496218   491.640082
# 2015-01-06  101.935070  101.090576  ...  102.443604   503.195808
# 2015-01-07  103.370750  104.907382  ...  106.203015   516.916998
# 2015-01-08  103.847950  105.997959  ...  107.330813   516.048717
# ...                ...         ...  ...         ...          ...
# 2020-12-17  116.921029  252.404450  ...  504.837440  1904.473516
# 2020-12-18  116.411413  251.755602  ...  510.568998  1903.375106
# 2020-12-21  112.261665  246.132190  ...  502.869059  1866.990620
# 2020-12-22  112.916890  246.564749  ...  503.332223  1870.544171
# 2020-12-23  112.844086  252.404450  ...  505.763769  1890.873127
#
# [1485 rows x 6 columns]

# %%
ibov_normalizado = (ibov/ibov.iloc[0])*500
ibov_normalizado
# Out:
# Date
# 2015-01-02     500.000000
# 2015-01-05     489.744805
# 2015-01-06     494.733262
# 2015-01-07     509.801699
# 2015-01-08     514.748928
#                  ...
# 2020-12-17    1217.812088
# 2020-12-18    1212.885472
# 2020-12-21    1195.745383
# 2020-12-22    1199.167216
# 2020-12-23    1214.720069
# Name: Adj Close, Length: 1477, dtype: float64

# %%
carteira_normalizada["Saldo"].plot(figsize=(22,8), label='Minha Carteira')
ibov_normalizado.plot(figsize=(22,8), label='Ibovespa')
plt.legend()
