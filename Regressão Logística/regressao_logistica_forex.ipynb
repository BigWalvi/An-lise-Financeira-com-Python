# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as wb

# %%
#importando dados

# %%
ativo = wb.get_data_yahoo('AUDJPY=X', start=2000)
ativo = ativo.drop(columns='Volume')
ativo = ativo.drop(columns='Adj Close')
ativo['MM10'] = ativo['Close'].rolling(10).mean()
ativo['MM20'] = ativo['Close'].rolling(20).mean()
ativo['MM100'] = ativo['Close'].rolling(100).mean()
ativo['MM200'] = ativo['Close'].rolling(200).mean()
ativo
# Out:
#                  High        Low       Open  ...       MM20      MM100      MM200
# Date                                         ...
# 2003-12-01  79.739998  78.820000  79.338997  ...        NaN        NaN        NaN
# 2003-12-02  79.923111  79.272598  79.370003  ...        NaN        NaN        NaN
# 2003-12-03  79.812798  79.190002  79.589996  ...        NaN        NaN        NaN
# 2003-12-04  79.739998  79.110001  79.730003  ...        NaN        NaN        NaN
# 2003-12-05  79.650002  79.095200  79.589996  ...        NaN        NaN        NaN
# ...               ...        ...        ...  ...        ...        ...        ...
# 2021-01-07  80.556999  80.150002  80.516998  ...  78.768950  76.558058  74.524294
# 2021-01-08  80.912003  80.489998  80.623001  ...  78.881800  76.603018  74.600139
# 2021-01-11  80.438538  80.001999  80.372002  ...  78.973550  76.647988  74.676004
# 2021-01-12  80.601997  80.181000  80.266998  ...  79.067101  76.690728  74.743559
# 2021-01-13  80.696999  80.589996  80.610001  ...  79.184901  76.731558  74.812724
#
# [4438 rows x 8 columns]

# %%
mais_recente = ativo.iloc[[-2]]
mais_recente
# Out:
#                  High     Low       Open  ...       MM20      MM100      MM200
# Date                                      ...
# 2021-01-12  80.601997  80.181  80.266998  ...  79.067101  76.690728  74.743559
#
# [1 rows x 8 columns]

# %%
ativo['Close'].plot(figsize=(22,8))

# %%
resultado = []
for i in range(0, len(ativo)):
  if ativo['Close'][i] > ativo['Open'][i]:
    resultado.append(1)
  else:
    resultado.append(0)

# %%
resultado.pop(0)
resultado.append('Espera')
ativo['Resultado'] = resultado

# %%
ativo = ativo.dropna()
#ativo['MM10'] = ativo['Close'] - ativo['MM10']
#ativo['MM20'] = ativo['Close'] - ativo['MM20']
#ativo['MM100'] = ativo['Close'] - ativo['MM100']
#ativo['MM200'] = ativo['Close'] - ativo['MM200']
#ativo['Close'] = ativo['Close'] / ativo['Open']
#ativo['Low'] = ativo['Low'] / ativo['Open']
#ativo['High'] = ativo['High'] / ativo['Open']
#ativo['Open'] = ativo['Open'] / ativo['Open']
#ativo

# %%
previsores = ativo.iloc[:len(ativo)-1,0:8]
classe = ativo.iloc[:len(ativo)-1,8]
classe = classe.astype('int')

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#previsores = scaler.fit_transform(previsores)

# %%
from sklearn.model_selection import train_test_split
previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.15, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
classificador = LogisticRegression(random_state=1)
classificador.fit(previsores_treinamento, classe_treinamento)
previsoes = classificador.predict(previsores_teste)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
precisao = accuracy_score(classe_teste, previsoes)
matriz = confusion_matrix(classe_teste, previsoes)

# %%
print(precisao)
print(matriz)
# Out:
# 0.5314465408805031
# [[ 91 217]
#  [ 81 247]]

# %%
# Conclusão: 53%
#Péssimo

# %%
teste1 = classificador.predict(mais_recente)

# %%
teste1
# Out:
# array([1])
