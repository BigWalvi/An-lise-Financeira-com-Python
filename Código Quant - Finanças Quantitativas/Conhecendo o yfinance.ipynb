# %%
pip install yfinance --upgrade --no-cache-dir

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
B3 = yf.Ticker("B3SA3.SA")

# %%
hist = B3.history(period='max', interval="1mo")
hist = hist.drop(columns=['Dividends', 'Stock Splits'])
hist = hist.dropna()
hist['Close'].plot(figsize=(22,8))
print(hist)
# Out:
#                  Open       High        Low      Close       Volume
# Date
# 2011-05-01   8.272704   8.411742   7.626182   7.869497  136527865.0
# 2011-06-01   7.834740   8.091959   7.104795   7.181265  249273300.0
# 2011-07-01   7.197458   7.636838   6.074599   6.304750  221058887.0
# 2011-08-01   6.458185   6.639516   5.230711   6.507004  483432300.0
# 2011-09-01   7.001957   7.221211   6.089581   6.216889  348227600.0
# ...               ...        ...        ...        ...          ...
# 2020-09-01  58.538389  59.850420  52.609578  54.266880  266142300.0
# 2020-10-01  55.330002  58.500000  50.380001  51.049999  254858100.0
# 2020-10-31  51.049999  58.299999  50.560001  56.130001  293161800.0
# 2020-12-01  56.799999  61.540001  54.860001  59.990002  193971600.0
# 2020-12-28  60.150002  60.779999  59.799999  60.689999    1977800.0
#
# [117 rows x 5 columns]

# %%
B3.actions

# %%
B3.dividends
