# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %% [markdown]
# #Obtendo dados do Mercado

# %%
petrobras = wb.get_data_yahoo('EURUSD=X', start='2000-1-1')

# %%
petrobras.head()
# Out:
#                 High       Low      Open     Close  Volume  Adj Close
# Date
# 2003-12-01  1.204007  1.194401  1.203398  1.196501     0.0   1.196501
# 2003-12-02  1.210903  1.194600  1.196101  1.208897     0.0   1.208897
# 2003-12-03  1.213003  1.207700  1.209000  1.212298     0.0   1.212298
# 2003-12-04  1.214403  1.204398  1.212004  1.208094     0.0   1.208094
# 2003-12-05  1.219096  1.206593  1.207802  1.218695     0.0   1.218695

# %%
petrobras.tail()
# Out:
#                 High       Low      Open     Close  Volume  Adj Close
# Date
# 2020-12-21  1.223466  1.213077  1.221061  1.221613     0.0   1.221613
# 2020-12-22  1.225900  1.216604  1.223840  1.223691     0.0   1.223691
# 2020-12-23  1.221941  1.215776  1.218591  1.218665     0.0   1.218665
# 2020-12-24  1.221747  1.217938  1.219393  1.219141     0.0   1.219141
# 2020-12-25  1.221300  1.216700  1.218472  1.218472     0.0   1.218472

# %%
petrobras['Adj Close'].plot(figsize=(22,8), label="PETR4")
petrobras['Adj Close'].rolling(21).mean().plot(label="MM21")
petrobras['Adj Close'].rolling(200).mean().plot(label='MM200')
plt.legend()

# %%
petro_fatiado = petrobras[petrobras.index.year == 2017]
petro_fatiado['Adj Close'].plot(figsize=(22,8), label="PETR4")
petro_fatiado['Adj Close'].rolling(21).mean().plot(label="MM21")
petro_fatiado['Adj Close'].rolling(200).mean().plot(label='MM200')
plt.legend()

# %%
petro_fatiado = petrobras[(petrobras.index.year >= 2004) & (petrobras.index.year <= 2010)]
petro_fatiado['Adj Close'].plot(figsize=(22,8), label="PETR4")
petro_fatiado['Adj Close'].rolling(21).mean().plot(label="MM21")
petro_fatiado['Adj Close'].rolling(200).mean().plot(label='MM200')
plt.legend()
