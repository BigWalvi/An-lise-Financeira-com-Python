# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %% [markdown]
# #Obtendo dados do Mercado

# %%
acao = wb.get_data_yahoo('ABEV3.SA', start='2000-1-1')

# %%
acao.head()
# Out:
#                High      Low     Open    Close  Volume  Adj Close
# Date
# 2000-01-05  0.52087  0.52087  0.52087  0.52087   986.0   0.093810
# 2000-01-06  0.49449  0.49449  0.49449  0.49449   228.0   0.089059
# 2000-01-07  0.49449  0.49449  0.49449  0.49449   152.0   0.089059
# 2000-01-10  0.49449  0.49449  0.49449  0.49449  1517.0   0.089059
# 2000-01-11  0.49449  0.49449  0.49449  0.49449  3792.0   0.089059

# %%
acao.tail()
# Out:
#                  High    Low   Open  Close      Volume  Adj Close
# Date
# 2020-12-18  16.049999  15.64  15.74  15.99  17456200.0      15.99
# 2020-12-21  15.790000  15.31  15.65  15.42  24879600.0      15.42
# 2020-12-22  15.750000  15.47  15.50  15.51  15406100.0      15.51
# 2020-12-23  15.730000  15.50  15.58  15.50  11560800.0      15.50
# 2020-12-23  15.500000  15.50   0.00  15.50         0.0      15.50

# %%
acao['Adj Close'].plot(figsize=(22,8), label="PETR4")
acao['Adj Close'].rolling(21).mean().plot(label="MM21")
acao['Adj Close'].rolling(200).mean().plot(label='MM200')
plt.legend()

# %%
acao_fatiada = acao[acao.index.year >= 2015]
acao_fatiada['Adj Close'].plot(figsize=(22,8), label="PETR4")
acao_fatiada['Adj Close'].rolling(21).mean().plot(label="MM21")
acao_fatiada['Adj Close'].rolling(200).mean().plot(label='MM200')
plt.legend()

# %%
acao_fatiado = acao[(acao.index.year >= 2019) & (acao.index.year <= 2020)]
acao_fatiado['Adj Close'].plot(figsize=(22,8), label="PETR4")
acao_fatiado['Adj Close'].rolling(21).mean().plot(label="MM21")
acao_fatiado['Adj Close'].rolling(200).mean().plot(label='MM200')
plt.legend()
